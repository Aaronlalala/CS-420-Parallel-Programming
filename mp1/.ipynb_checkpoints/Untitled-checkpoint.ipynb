# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("data.xlsx")

# %%
sns.catplot(data=data, x="Tile", y="MFLOPS", col="Matrix", kind="bar",col_wrap=3, height=5)
plt.savefig("result.png")
plt.show()
